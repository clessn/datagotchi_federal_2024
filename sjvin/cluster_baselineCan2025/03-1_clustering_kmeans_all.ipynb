# %% [markdown]
# # Clustering
#
# Dans cet essai qui constitue le baseline des clusters pour le jeu de données,
#
# - Toutes les variables disponibles sont utilisées
# - L'algorithme du k-means est utilisé (même si les variables ne sont pas tout à fait adéquates pour ce genre de méthode étant donné qu'elles sont binaires et ordinales plutôt que continues)
#
# À la fin de cette étape, nous aurons :
#
# - Les valeurs des moyennes et ecart-type pour le scaling des variables (`03_pilot1_scale_origins.rds` et `03_pilot1_scale_ecarts_types.rds`)
# - Le modèle de k-means (`03_pilot1_kmeans.rds`)
# - Le fichier de données original augmenté des variables de cluster (`03_pilot1_2022.rds`)
# - Un fichier csv (pour ouverture dans excel par exemple) qui contient la moyenne par cluster par variable afin de déterminer "à la main" quels sont les éléments distinctifs de chaque cluster (`03_pilot1_clusters_desc.csv`)

# %%
library(dplyr)
library(factoextra)

df_pilot_2025 <- readRDS(file = "../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/02_pilot_2025.rds")

# %%
# Sélection des variables pour le clustering
source("03-0_variables.R")
df_pilot_2025_clust <- df_pilot_2025 %>% select(all_of(variables_clust)) %>% select(-id)

# %%
# Scaling des variables
df_scaled <- scale(df_pilot_2025_clust)

# Récupérer les moyennes et écarts-types
origines <- attr(df_scaled, "scaled:center")  # Moyennes utilisées pour centrer
ecarts_types <- attr(df_scaled, "scaled:scale")  # Écarts-types utilisés pour réduire

# %%
# Détermination du nombre optimal de clusters
# Méthode de l’élbow (coude) et l’indice de silhouette.

# Méthode du coude
fviz_nbclust(df_scaled, kmeans, method = "wss") +
  ggtitle("Méthode du coude")

# Indice de silhouette
fviz_nbclust(df_scaled, kmeans, method = "silhouette") +
  ggtitle("Indice de silhouette")
# Out:
# plot without title
# plot without title

# %%
# Application de K-Means Clustering

# Choisissez un nombre de clusters approprié (par exemple, 3).
k <- 8

# K-Means Clustering
set.seed(123)  # Pour la reproductibilité
kmeans_result <- kmeans(df_scaled, centers = k, nstart = 25)

# %%
kmeans_result
# Out:
# K-means clustering with 8 clusters of sizes 18, 150, 51, 75, 402, 51, 246, 39
#
# Cluster means:
#   lifestyle_exerciseGym lifestyle_exerciseTeamSport lifestyle_exerciseWalk
# 1            0.14899896                 -0.24612689            -0.12462805
# 2            0.67943524                  0.55749827            -0.56001259
# 3           -0.13146967                  0.17594515             0.12364045
# 4           -0.44699687                 -0.24612689            -1.01316794
# 5           -0.14677509                 -0.12832470             0.27985652
# 6            0.07888180                  0.09153074            -0.11156129
# 7           -0.03270709                 -0.08862196             0.20586544
# 8           -0.03438437                 -0.02535075            -0.03919152
#   lifestyle_exerciseRun lifestyle_exerciseYoga lifestyle_exerciseSwim
# 1            0.05318997            -0.14751634            -0.14751634
# 2            0.30074237             0.08314558            -0.10138396
# 3           -0.12091977             0.12385062            -0.01183286
# 4           -0.21588872            -0.14751634            -0.14751634
# 5           -0.03516422            -0.02702131             0.02461942
# 6           -0.02595082            -0.14751634            -0.01183286
# 7           -0.05837924             0.07751967             0.07751967
# 8            0.15668178            -0.14751634             0.02991590
#   lifestyle_exerciseOther lifestyle_exerciseNone
# 1              0.43920479             -0.1149937
# 2             -0.27626755             -0.2873249
# 3              0.01386140             -0.1725910
# 4             -0.32193600              3.2141312
# 5              0.13815656             -0.3108246
# 6             -0.05329808              0.1729929
# 7              0.02614668             -0.3108246
# 8             -0.05846419              0.1410928
#   lifestyle_goFishingFreq_numeric lifestyle_goHuntingFreq_numeric
# 1                     0.386045545                     0.713438604
# 2                     0.849847931                     1.174605317
# 3                    -0.024257577                    -0.146045079
# 4                    -0.182837069                    -0.154102738
# 5                    -0.069590544                    -0.218503883
# 6                     0.007714095                     0.015108112
# 7                    -0.354111654                    -0.336186191
# 8                    -0.122631951                    -0.006585587
#   lifestyle_goMuseumsFreq_numeric lifestyle_motorizedActFreq_numeric
# 1                      0.25195972                         0.28330043
# 2                      0.56022342                         0.86699021
# 3                     -0.16604491                        -0.02325933
# 4                     -0.56874233                        -0.23785116
# 5                     -0.10356829                        -0.14062139
# 6                     -0.06007191                         0.13002055
# 7                     -0.00191599                        -0.25056218
# 8                      0.19806746                        -0.11758541
#   lifestyle_volunteeringFreq_numeric lifestyle_clothingStyleClassic
# 1                         0.21131982                      0.4543187
# 2                         0.61971318                      1.0650902
# 3                        -0.04332545                     -0.0740303
# 4                        -0.71328274                     -0.2642359
# 5                        -0.01664901                     -0.1958660
# 6                        -0.24511982                     -0.0211954
# 7                        -0.07355945                     -0.1919423
# 8                        -0.09654594                     -0.4438746
#   lifestyle_clothingStyleCasual lifestyle_clothingStyleSport
# 1                   -0.43211416                  -0.23256056
# 2                   -1.01754007                   0.40140831
# 3                    0.04700678                   0.21139523
# 4                    0.43329804                  -0.23256056
# 5                    0.30109284                  -0.08612141
# 6                    0.13684196                  -0.05497825
# 7                    0.26009144                  -0.01166549
# 8                   -1.70477917                  -0.23256056
#   lifestyle_clothingStyleOther lifestyle_hasTattoos lifestyle_ownPetCat
# 1                    0.3652849           0.08719433         -0.50217784
# 2                   -0.2033034           0.37982702         -0.20318888
# 3                   -0.2033034           0.25933121          0.23063824
# 4                   -0.2033034           0.02866780          0.12902108
# 5                   -0.2033034          -0.18032436         -0.04352977
# 6                   -0.2033034           0.30236543          0.08407502
# 7                   -0.2033034          -0.18045752          0.07513824
# 8                    4.9139913           0.70622502          0.32834705
#   lifestyle_ownPetDog lifestyle_ownPetOther lifestyle_ownPetCatAndDog
# 1         -0.50670960             7.5019162              -0.289745035
# 2          0.53418239            -0.1331701               0.258452572
# 3         -0.21514322            -0.1331701              -0.216456585
# 4         -0.14322351            -0.1331701               0.059107987
# 5          0.02347703            -0.1331701               0.082166503
# 6          0.07642317            -0.1331701              -0.069879685
# 7         -0.26492284            -0.1331701              -0.228969247
# 8          0.06520907            -0.1331701              -0.002228808
#   lifestyle_ownPetNone lifestyle_eatMeatFreq lifestyle_favAlcoolRedWine
# 1          -0.93933799            0.41339033                 0.13733935
# 2          -0.43194021           -0.26323629                 0.04284988
# 3           0.08174113           -0.07569671                 0.01575363
# 4           0.02204727            0.10374764                -0.20518499
# 5           0.02722887            0.08817136                -0.03013266
# 6          -0.15389251            0.43025540                 0.17207813
# 7           0.33078481           -0.09708656                 0.06531994
# 8          -0.22035328           -0.13796774                -0.18065407
#   lifestyle_favAlcoolWhiteWine lifestyle_favAlcoolRoseWine
# 1                  -0.38775745                -0.181661840
# 2                   0.14579680                 0.234949314
# 3                  -0.09715056                 0.041124873
# 4                   0.24460314                 0.197075572
# 5                   0.01779097                -0.125133868
# 6                  -0.15527194                -0.070268484
# 7                  -0.09856815                 0.003088117
# 8                  -0.08373793                 0.109674631
#   lifestyle_favAlcoolSpirits lifestyle_favAlcoolBubbleDrink
# 1                 0.08083716                    -0.18727333
# 2                -0.12282695                     0.18085253
# 3                -0.17259103                    -0.18727333
# 4                -0.12282695                    -0.11364816
# 5                 0.08376001                    -0.02244086
# 6                 0.17299287                    -0.07900102
# 7                -0.05290100                     0.03719366
# 8                 0.14109282                    -0.04568646
#   lifestyle_favAlcoolBeer lifestyle_favAlcoolMicroBeer
# 1            -0.066398454                  -0.06256618
# 2             0.233798442                  -0.17448455
# 3            -0.277534378                  -0.20183113
# 4            -0.001138259                  -0.12282992
# 5             0.001783839                   0.10768853
# 6             0.010378246                   0.02605697
# 7            -0.094253415                   0.02142510
# 8             0.059101920                  -0.07912215
#   lifestyle_favAlcoolCocktail lifestyle_favAlcoolDontDrink lifestyle_smokeFreq
# 1                  0.19069004                  0.241070039          0.22060644
# 2                 -0.08890532                 -0.264396436          0.77631256
# 3                  0.28557535                  0.380444987         -0.04498839
# 4                 -0.04589065                  0.146295075          0.33869399
# 5                 -0.07413909                  0.005311422         -0.23686618
# 6                  0.09580474                 -0.177054802          0.26146719
# 7                  0.08577621                  0.038806397         -0.26436574
# 8                  0.06660926                  0.058810493          0.08702324
#   ses_dwellingApp ses_dwellingCondo ses_dwellingDetachedHouse
# 1     -0.23804703       -0.42972770                 0.2927364
# 2      0.27778402        0.23135899                -0.2274426
# 3     -0.39924423       -0.42972770                -1.0410558
# 4      0.06500371       -0.09918436                 0.2393847
# 5     -0.39924423       -0.42972770                 0.9596325
# 6     -0.39924423       -0.42972770                -1.0410558
# 7      0.62691357        0.79077448                -1.0410558
# 8      0.12154673        0.06467474                -0.3228600
#   ses_dwellingTownhouse ses_dwellingDuplex ses_dwellingOther
# 1           0.327716349       -0.234864261         0.2444976
# 2           0.129501977       -0.204940815        -0.2416710
# 3          -0.291703564       -0.234864261         4.1338467
# 4           0.005617995       -0.234864261        -0.2416710
# 5          -0.291703564       -0.234864261        -0.2416710
# 6          -0.291703564        4.253652734        -0.2416710
# 7           0.463686574       -0.234864261        -0.2416710
# 8           0.184773293       -0.004683903         0.2071000
#   lifestyle_typeTransportCar lifestyle_typeTransportActive
# 1                 0.07643485                   -0.33101532
# 2                -0.36179163                   -0.10774224
# 3                -0.18134543                   -0.06834111
# 4                 0.07643485                   -0.24170609
# 5                 0.07643485                   -0.09774494
# 6                 0.07643485                   -0.13400966
# 7                 0.07643485                    0.33608107
# 8                 0.07643485                    0.18423025
#   lifestyle_typeTransportPublicTransit lifestyle_consClothesFrip
# 1                          0.008303387                0.35634491
# 2                          0.101135256               -0.24593978
# 3                          0.344346352                0.27298371
# 4                          0.036867039                0.07291682
# 5                         -0.180877517               -0.01115980
# 6                         -0.033701983                0.21046281
# 7                          0.160700921                0.01070090
# 8                         -0.019161663                0.05656520
#   lifestyle_consClothesIndependent lifestyle_consClothesChain
# 1                      -0.01314022               -0.200279263
# 2                       0.45279184                0.044684529
# 3                      -0.17676869               -0.312854535
# 4                      -0.27740020                0.029374292
# 5                      -0.01054537               -0.040321563
# 6                      -0.11540802                0.002356227
# 7                      -0.10642840                0.126463600
# 8                      -0.03988718               -0.111950973
#   lifestyle_consClothesSuperstores lifestyle_consClothesDepartment
# 1                      -0.01765381                     0.082307054
# 2                      -0.10214645                     0.059656152
# 3                       0.10660009                    -0.034278467
# 4                       0.15133149                    -0.008296551
# 5                       0.07495707                    -0.027566721
# 6                      -0.07978075                    -0.034278467
# 7                      -0.08205369                    -0.017826503
# 8                      -0.18013966                     0.234765042
#   lifestyle_consClothesOnline lifestyle_consClothesOther
# 1                 -0.27576657                0.149416113
# 2                 -0.19779640               -0.097820271
# 3                  0.18288145                0.168552056
# 4                 -0.06784613                0.058329024
# 5                  0.03456244               -0.030233262
# 6                  0.18288145               -0.175894918
# 7                  0.07288051               -0.009272195
# 8                 -0.27576657                0.574822847
#   lifestyle_consCoffeeTimHortons lifestyle_consCoffeeStarbucks
# 1                     0.14813459                   -0.03352724
# 2                     0.27195849                    0.33961120
# 3                     0.19715989                   -0.07343509
# 4                    -0.22809958                   -0.16921394
# 5                    -0.04556239                   -0.12972304
# 6                     0.02907314                   -0.13329687
# 7                    -0.04062136                    0.02438782
# 8                    -0.24568404                    0.48834470
#   lifestyle_consCoffeeMcDo lifestyle_consCoffeeOther
# 1              0.214649445             -0.1440534134
# 2              0.192607830              0.4694769340
# 3              0.182235306             -0.1440534134
# 4             -0.160058004             -0.1440534134
# 5              0.000812885             -0.1264434723
# 6             -0.206734365             -0.0052456425
# 7             -0.081030752             -0.0001673094
# 8              0.002710843              0.0374644409
#   lifestyle_consCoffeeIndependent lifestyle_consCoffeeNone
# 1                    0.1622095181             -0.298860359
# 2                   -0.1429471379             -0.676898611
# 3                   -0.1198680630             -0.149706099
# 4                    0.0401468557              0.457216144
# 5                   -0.0004539445              0.169042828
# 6                   -0.1198680630              0.257078246
# 7                    0.1568932001             -0.009315892
# 8                   -0.2737285619              0.038040522
#
# Clustering vector:
#    [1] 6 5 5 7 4 8 5 5 6 7 5 7 2 2 7 7 2 5 7 2 7 8 2 7 4 4 6 4 5 7 4 5 7 2 5 7 8
#   [38] 7 5 7 6 5 7 5 2 5 5 5 5 7 7 7 7 5 8 8 5 5 2 5 5 7 7 7 5 5 2 2 7 7 7 4 3 6
#   [75] 7 5 4 5 5 5 5 5 2 5 7 5 5 5 8 5 2 5 5 3 6 5 2 5 2 7 5 5 8 8 7 5 4 6 5 1 2
#  [112] 3 5 4 4 7 5 5 2 2 5 5 5 4 2 5 7 7 5 2 7 5 5 7 7 4 2 5 5 1 2 5 5 5 7 5 7 6
#  [149] 2 4 2 5 3 4 5 5 5 8 7 5 6 6 7 5 6 5 7 5 7 4 5 1 5 6 7 7 5 5 5 6 5 5 4 5 7
#  [186] 5 5 7 5 5 7 7 7 5 4 5 7 4 5 5 5 4 5 3 6 5 7 7 5 7 5 8 5 5 5 5 3 7 5 8 2 5
#  [223] 7 3 5 4 6 7 4 2 4 5 7 1 5 3 5 5 7 7 8 5 3 7 8 5 7 5 7 7 5 5 3 7 5 4 5 5 4
#  [260] 5 4 1 4 5 3 5 5 5 5 4 5 2 5 7 8 5 5 5 3 1 8 5 4 2 5 5 5 3 4 4 7 5 5 3 7 5
#  [297] 5 6 8 5 7 5 5 7 4 5 2 1 8 6 5 5 5 4 7 5 5 5 4 7 8 5 5 5 5 2 2 5 7 5 7 2 7
#  [334] 5 3 2 7 5 2 6 5 2 5 7 2 5 2 2 7 5 6 7 7 7 3 5 5 7 5 5 1 5 5 7 2 7 5 6 7 2
#  [371] 4 5 5 3 5 5 3 5 2 1 5 2 5 2 7 5 5 7 5 5 3 5 5 5 7 6 7 5 7 5 5 7 7 2 2 3 7
#  [408] 3 5 7 2 7 7 5 2 5 5 7 3 5 7 4 2 2 5 1 7 6 6 5 7 7 5 5 5 5 5 5 7 8 4 5 4 2
#  [445] 7 5 5 3 7 3 7 5 2 7 6 7 5 5 1 5 4 4 7 5 5 3 7 5 2 7 5 7 5 7 7 3 7 7 7 5 2
#  [482] 7 2 6 2 7 3 5 7 5 5 4 7 5 5 7 4 4 7 5 2 5 7 3 2 2 5 1 7 2 3 7 7 5 5 2 5 7
#  [519] 2 5 2 7 2 7 7 4 5 5 7 7 6 4 4 6 5 2 5 2 5 2 5 2 2 2 8 8 5 5 5 7 3 3 5 8 2
#  [556] 4 2 3 7 5 7 2 7 5 7 3 7 5 6 7 5 7 2 7 8 7 5 5 5 2 2 5 8 2 7 5 6 5 7 2 8 7
#  [593] 2 5 5 5 5 2 5 6 7 5 5 2 5 4 7 4 5 1 5 7 2 2 5 5 2 5 5 7 2 7 5 6 5 2 7 3 2
#  [630] 4 5 7 5 5 5 4 4 2 2 2 5 5 7 7 2 4 7 7 5 7 2 8 5 5 5 7 5 2 5 8 2 7 2 5 5 7
#  [667] 5 4 5 7 7 5 7 5 5 5 2 5 2 2 2 2 7 5 7 7 7 7 7 5 2 4 2 5 2 5 2 2 7 7 1 6 2
#  [704] 5 2 5 5 5 6 5 8 5 2 7 5 7 7 3 5 7 7 6 2 3 5 7 2 7 5 2 7 7 5 5 5 7 5 5 7 4
#  [741] 2 8 7 7 7 5 2 4 5 5 5 7 7 7 7 8 2 5 5 5 7 7 4 2 5 5 5 5 5 5 3 5 3 5 8 6 5
#  [778] 7 8 7 5 7 2 5 6 7 7 2 3 5 3 3 5 5 3 5 2 7 5 5 6 5 2 2 5 2 5 6 7 2 8 6 4 4
#  [815] 7 2 5 5 7 5 1 5 5 4 2 5 5 3 7 6 2 7 5 2 5 7 2 4 4 5 5 5 8 5 6 5 5 7 5 4 5
#  [852] 5 2 2 2 2 5 7 2 2 2 5 7 5 7 2 6 7 5 7 5 7 1 3 7 5 7 5 7 5 5 7 7 4 2 7 7 2
#  [889] 5 5 5 7 7 5 5 2 2 2 5 5 5 5 3 7 2 5 6 7 6 4 1 2 7 1 4 2 8 5 2 7 7 5 2 5 2
#  [926] 5 3 4 7 4 5 5 5 8 8 5 5 5 6 5 7 5 5 7 2 7 5 5 8 3 7 4 4 7 5 5 8 4 5 5 5 5
#  [963] 7 5 4 2 5 5 3 4 6 7 4 7 7 5 5 7 7 3 5 5 7 5 6 5 2 5 5 4 6 5 5 5 5 5 5 6 5
# [1000] 5 7 7 5 5 5 7 2 7 3 5 7 7 7 5 7 5 5 7 7 7 2 2 5 6 5 5 5 7 6 5 3 5
#
# Within cluster sum of squares by cluster:
# [1]   829.1329 10195.0931  2485.3518  2835.5357 16034.5465  2221.9974 12213.4392
# [8]  2112.9653
#  (between_SS / total_SS =  15.3 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"

# %%
# Visualisation des clusters

# Visualisation des clusters dans l’espace des deux premières dimensions :

# Utilisation de factoextra pour représenter les clusters
fviz_cluster(kmeans_result, data = df_scaled, ellipse.type = "euclid") +
  ggtitle("Visualisation des clusters avec K-Means")
# Out:
# plot without title

# %%
library(dplyr)
library(tidyr)

# Ajouter les clusters au dataframe original
df_pilot_2025$cluster <- as.factor(kmeans_result$cluster)

# Préparer les données pour pouvoir donner des noms aux clusters
df_pilot_2025 <- df_pilot_2025 %>%
  mutate(cluster_name = as.character(cluster))

# Créer des variables dummy
# Liste des clusters
clusters_uniques <- unique(df_pilot_2025$cluster)
# Création des variables
for (i in clusters_uniques) {
  df_pilot_2025[[paste0("cluster_", i)]] <- ifelse(df_pilot_2025$cluster == i, 1, 0)
}

# %%
# Sauvegarder les résultats du clustering
saveRDS(origines, file="../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/03_pilot_scale_origins.rds")
saveRDS(ecarts_types, file="../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/03_pilot_scale_ecarts_types.rds")
saveRDS(kmeans_result, file = "../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/03_pilot_kmeans.rds")
saveRDS(df_pilot_2025, file = "../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/03_pilot_2025.rds")
