# %% [markdown]
# # Clustering
#
# Dans cet essai qui constitue le baseline des clusters pour le jeu de données,
#
# - Toutes les variables disponibles sont utilisées
# - L'algorithme du k-means est utilisé (même si les variables ne sont pas tout à fait adéquates pour ce genre de méthode étant donné qu'elles sont binaires et ordinales plutôt que continues)
#
# À la fin de cette étape, nous aurons :
#
# - Les valeurs des moyennes et ecart-type pour le scaling des variables (`03_pilot1_scale_origins.rds` et `03_pilot1_scale_ecarts_types.rds`)
# - Le modèle de k-means (`03_pilot1_kmeans.rds`)
# - Le fichier de données original augmenté des variables de cluster (`03_pilot1_2022.rds`)
# - Un fichier csv (pour ouverture dans excel par exemple) qui contient la moyenne par cluster par variable afin de déterminer "à la main" quels sont les éléments distinctifs de chaque cluster (`03_pilot1_clusters_desc.csv`)

# %%
library(dplyr)
library(factoextra)

df_pilot_2025 <- readRDS(file = "../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/02_pilot_2025.rds")

# %%
# Sélection des variables pour le clustering
source("03-0_variables.R")
df_pilot_2025_clust <- df_pilot_2025 %>% select(all_of(variables_clust)) %>% select(-id)

# %%
# Scaling des variables
df_scaled <- scale(df_pilot_2025_clust)

# Récupérer les moyennes et écarts-types
origines <- attr(df_scaled, "scaled:center")  # Moyennes utilisées pour centrer
ecarts_types <- attr(df_scaled, "scaled:scale")  # Écarts-types utilisés pour réduire

# %%
# Détermination du nombre optimal de clusters
# Méthode de l’élbow (coude) et l’indice de silhouette.

# Méthode du coude
fviz_nbclust(df_scaled, kmeans, method = "wss", k.max = 15) +
  ggtitle("Méthode du coude")

# Indice de silhouette
fviz_nbclust(df_scaled, kmeans, method = "silhouette", k.max = 15) +
  ggtitle("Indice de silhouette")
# Out:
# plot without title
# plot without title

# %%
# Application de K-Means Clustering

# Choisissez un nombre de clusters approprié (par exemple, 3).
k <- 11

# K-Means Clustering
set.seed(123)  # Pour la reproductibilité
kmeans_result <- kmeans(df_scaled, centers = k, nstart = 25)

# %%
kmeans_result
# Out:
# K-means clustering with 11 clusters of sizes 22, 123, 77, 66, 136, 71, 128, 148, 118, 41, 91
#
# Cluster means:
#    lifestyle_exerciseGym lifestyle_exerciseYoga lifestyle_exerciseNone
# 1            -0.44830730              6.7353260             -0.3126558
# 2            -0.23068653             -0.1483255             -0.3126558
# 3            -0.44830730             -0.1483255              3.1952732
# 4            -0.24552431             -0.1483255             -0.3126558
# 5             0.22087655             -0.1483255             -0.2094814
# 6            -0.03360182             -0.1483255             -0.1150260
# 7            -0.15553936             -0.1483255             -0.2852501
# 8            -0.15893050             -0.1483255             -0.3126558
# 9             1.11690237             -0.1483255             -0.3126558
# 10           -0.05658992             -0.1483255              0.1151404
# 11           -0.27181925             -0.1483255             -0.3126558
#    lifestyle_goHuntingFreq_numeric lifestyle_clothingStyleOther
# 1                       0.04254763                   -0.2044401
# 2                      -0.05738017                   -0.2044401
# 3                      -0.18531390                   -0.2044401
# 4                      -0.11382793                   -0.2044401
# 5                      -0.04713835                   -0.2044401
# 6                      -0.07770738                   -0.2044401
# 7                      -0.16855938                   -0.2044401
# 8                      -0.24526793                   -0.2044401
# 9                       0.79792110                   -0.2044401
# 10                      0.02652867                    4.8866173
# 11                      0.02708192                   -0.2044401
#    lifestyle_hasTattoos lifestyle_ownPetCat lifestyle_ownPetDog
# 1           -0.14202169         -0.16502312         0.387492325
# 2            0.05540877          0.85017327         0.112000719
# 3            0.12922757          0.14170137        -0.093379967
# 4            0.12446881          0.09865232        -0.248327706
# 5           -0.25371256         -0.21155408        -0.201576233
# 6           -0.11527880         -0.11886666         0.011373434
# 7           -0.04052628          0.03979619        -0.105151320
# 8           -0.38915561         -0.50403441        -0.510135954
# 9            0.64389944         -0.23014394         0.975134567
# 10           0.75250892          0.28423573         0.031725019
# 11          -0.25513372          0.04235741         0.005260503
#    lifestyle_ownPetNone lifestyle_eatMeatFreq lifestyle_favAlcoolRedWine
# 1         -0.1163901978           -0.05391300                 0.26874017
# 2         -0.8870758163            0.31085224                -0.13115036
# 3          0.0006880209            0.04675893                -0.21348077
# 4          0.0657314757           -0.13221340                 0.02762970
# 5          0.3456096357           -0.16675769                 0.07195148
# 6         -0.0330246430            0.13687528                -0.45459123
# 7          0.1439868823            0.01215295                 0.33278514
# 8          1.0132563987           -0.03804130                 0.19054218
# 9         -0.7322083990           -0.10965227                 0.21970075
# 10        -0.2518709549           -0.06728136                -0.19583854
# 11        -0.0993788327            0.00889940                -0.45459123
#    lifestyle_favAlcoolWhiteWine lifestyle_favAlcoolBeer
# 1                    0.28425000             -0.12936924
# 2                   -0.24409559             -0.32383259
# 3                    0.30347109              0.02249738
# 4                    0.23940079             -0.17366367
# 5                   -0.17083759             -0.07269842
# 6                   -0.38848818             -0.39513582
# 7                    0.42089994             -0.39513582
# 8                    0.03151863             -0.39513582
# 9                    0.13830002             -0.27126157
# 10                  -0.09970301              0.03268356
# 11                  -0.38848818              2.52829662
#    lifestyle_favAlcoolMicroBeer lifestyle_favAlcoolDontDrink
# 1                   -0.27736041                   0.10353998
# 2                   -0.27736041                   0.42166545
# 3                   -0.27736041                   0.10353998
# 4                   -0.27736041                   0.31972470
# 5                   -0.27736041                   0.27680567
# 6                    3.60188592                  -0.54501415
# 7                   -0.27736041                  -0.17344668
# 8                   -0.27736041                   0.16196828
# 9                   -0.27736041                  -0.30318040
# 10                  -0.08812889                   0.03499361
# 11                  -0.27736041                  -0.54501415
#    lifestyle_smokeFreq ses_dwellingApp lifestyle_typeTransportCar
# 1          -0.47453842      0.52612233                -0.04588630
# 2           0.01942664     -0.20944726                 0.51318191
# 3           0.33475498      0.05440669                 0.22566111
# 4           0.09196696      0.74625629                 0.25228341
# 5          -0.10797612      0.22117204                -1.94671822
# 6          -0.25511732     -0.23473506                 0.06277766
# 7          -0.23111814     -0.10332322                 0.01351469
# 8          -0.30611790     -0.26100533                 0.51318191
# 9           0.43643104      0.04481248                 0.51318191
# 10          0.13341857      0.09766647                -0.14679130
# 11          0.29584665     -0.11105664                 0.35099069
#    lifestyle_typeTransportNoCar lifestyle_consClothesFrip
# 1                  -0.059007776                0.08183860
# 2                  -0.508611804                0.45034697
# 3                  -0.251695217                0.06115100
# 4                  -0.246342788               -0.06297459
# 5                   1.964210347                0.06906097
# 6                  -0.090670032               -0.08337082
# 7                  -0.006319804               -0.07881353
# 8                  -0.508611804               -0.15886441
# 9                  -0.508611804               -0.19060656
# 10                  0.154828285                0.11362686
# 11                 -0.345568585               -0.10753250
#    lifestyle_consCoffeeTimHortons lifestyle_consCoffeeIndependent
# 1                   -0.0002865758                     0.083968191
# 2                   -0.2992239494                     0.078159822
# 3                   -0.1814161174                    -0.018093146
# 4                    0.1947760075                    -0.273246487
# 5                    0.1216275388                     0.073461876
# 6                   -0.0785863451                     0.003469108
# 7                   -0.2806890393                     0.463508785
# 8                   -0.0306003556                    -0.193597268
# 9                    0.5534927921                    -0.073448447
# 10                  -0.2643347068                    -0.177408403
# 11                   0.1422591582                    -0.186886894
#    lifestyle_consCoffeeNone     ses_age ses_languageEnglish ses_languageFrench
# 1               0.084597999 -0.21664840          0.14756181        -0.05886043
# 2               0.197169568  0.16246488          0.70475129        -0.65387526
# 3               0.474824225  0.31130756         -0.09857097         0.19614593
# 4              -0.009594539  0.39930022         -1.35202495         1.49478941
# 5              -0.214601826 -0.35731487          0.45864630        -0.58970700
# 6              -0.062660757  0.12015863          0.24732455        -0.16221981
# 7               0.192036362  0.12897350         -1.36747946         1.47671171
# 8               0.174971920  0.36502645          0.47998889        -0.65387526
# 9              -0.657766915 -0.89554292          0.56125957        -0.56142945
# 10             -0.004999781 -0.04167304         -0.15126606         0.19752808
# 11             -0.011664704  0.12497016         -0.31945936         0.28114805
#    ses_educBHS ses_educUniv ses_incomeLow ses_incomeHigh ses_immigrant
# 1  -0.18193380    0.3429295   -0.26840198     0.60743504   0.580112745
# 2   0.20127792   -0.3620541    0.07098371    -0.16460703  -0.223249308
# 3   0.27970626   -0.3597267    0.16428037    -0.05074792  -0.106441201
# 4   1.30380431   -0.8715380    0.74119017    -0.28842510  -0.396691649
# 5  -0.13768939    0.2464864    0.45199753    -0.18867597   0.454277355
# 6  -0.27453085    0.1966802   -0.35928382     0.09912003  -0.111629860
# 7  -0.49707278    0.2731925   -0.33218736     0.06751933  -0.273370095
# 8   0.03038621    0.1102933   -0.08688894     0.13529254   0.239551213
# 9  -0.37079881    0.4602594   -0.25277823     0.22783329   0.115220077
# 10  0.26106982   -0.3457625    0.30651953    -0.14171630  -0.474836001
# 11  0.02255928   -0.1835622   -0.30457944    -0.01418220   0.006911045
#    ses_regionQuebec
# 1       -0.03554332
# 2       -0.57162108
# 3        0.17072644
# 4        1.37625857
# 5       -0.49135903
# 6       -0.20230225
# 7        1.34216676
# 8       -0.60919623
# 9       -0.54783815
# 10       0.11706276
#  [649]  4  7  6 10  9  2  9  7  8  4  9  3 11  5  5  7  5  9  2  4  9  8  9  9
#  [673]  7  9  9  9  7  5  7  8  8  9  3  5  2  9  8  9  7  9  8  9  7  6  8  4
#  [697]  9  9  9  9  5 10  6  9  6  7  5  1  4  9  8  7  6  5  2  5  5  5  6  8
#  [721]  7  9  9  2  2  2  7 11  8  6  3 11 10  5  6  8  2  5  3  7  8  2  5  8
#  [745]  5  8 10  9  8  5  8  6  9  3  8  2  8  1  2  2  5  5  5  8  2 10  7  2
#  [769]  5 10  7 11  5  9  5  6  7  5  8  7  5  8  5  8  7 11  9 11  7  8  3  2
#  [793]  9 11 11 11  6 11  2  9 10  8  3  3  2  9  8 11  5  5  8  7  5  3  9  8
#  [817]  7  5  9  7  9  5  8  8  4  7  9  3  3  4  6  8 10  8  3  2  2  8  8  3
#  [841]  8  8  9  5 11  9  6  7  2  5  9  8  6  9  5  5  7  5  8 11  8  2 11  5
#  [865]  5  8  2  7  8  8  2  5  4  5  1  8  7 11 11  7  5  7  7  7  7  4  9  7
#  [889] 11 11  7  4  5  4  7  7  7  7  3  4 11  4  7  3  9 10  2  4  7  7  7  7
#  [913]  7 11  4  6  3  8  3  7 11  7 10 10  6  7  7  7  6  4  7  7  4  7  8  7
#  [937]  4 10  3  7  3  3  7  7  6 10  3  7  7  4  6  4 11  3  7 11  7  4  3  4
#  [961]  5  3  7 11  7  7  4  4  7 11  7  4 11 11  7  8  7  4  6  8 11  7  7  4
#  [985]  4  5  3  4  4  2  4  7  7  7  6  7  8  7  7  4  1  5  4  4  7  7 11  4
# [1009]  8 11  5  4  3  7  8  4  7  3  6  7  8
#
# Within cluster sum of squares by cluster:
#  [1]  621.2171 2552.4542 2115.4047 1490.7525 3377.5968 1444.4022 2851.6392
#  [8] 2462.5320 2687.5955 1210.5421 1868.7159
#  (between_SS / total_SS =  30.5 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"

# %%
# Visualisation des clusters

# Visualisation des clusters dans l’espace des deux premières dimensions :

# Utilisation de factoextra pour représenter les clusters
fviz_cluster(kmeans_result, data = df_scaled, ellipse.type = "euclid") +
  ggtitle("Visualisation des clusters avec K-Means")
# Out:
# plot without title

# %%
library(dplyr)
library(tidyr)

# Ajouter les clusters au dataframe original
df_pilot_2025$cluster <- as.factor(kmeans_result$cluster)

# Préparer les données pour pouvoir donner des noms aux clusters
df_pilot_2025 <- df_pilot_2025 %>%
  mutate(cluster_name = as.character(cluster))

# Créer des variables dummy
# Liste des clusters
clusters_uniques <- unique(df_pilot_2025$cluster)
# Création des variables
for (i in clusters_uniques) {
  df_pilot_2025[[paste0("cluster_", i)]] <- ifelse(df_pilot_2025$cluster == i, 1, 0)
}

# %%
# Sauvegarder les résultats du clustering
saveRDS(origines, file="../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/03_pilot_scale_origins.rds")
saveRDS(ecarts_types, file="../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/03_pilot_scale_ecarts_types.rds")
saveRDS(kmeans_result, file = "../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/03_pilot_kmeans.rds")
saveRDS(df_pilot_2025, file = "../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/03_pilot_2025.rds")
