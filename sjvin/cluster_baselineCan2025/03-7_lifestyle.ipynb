# %%
# Library
library(ggplot2)
library(dplyr)

# Load Data and Clustering Results
dfLifestyle <- readRDS("../../_SharedFolder_datagotchi_federal_2024/data/pilote/dataClean/datagotchi2025_canada_pilotClustering_20250319.rds")
dfUsedForClustering <- readRDS("../../_PrivateFolder_datagotchi_federal_2025/data/clustering/can2025/03_pilot_2025.rds")

# %%
names(dfLifestyle)
# Out:
#   [1] "id"
#   [2] "ses_gender"
#   [3] "ses_genderMale"
#   [4] "ses_genderFemale"
#   [5] "ses_age"
#   [6] "ses_ageGroup5Years"
#   [7] "ses_age_4Cat"
#   [8] "ses_province"
#   [9] "ses_region"
#  [10] "ses_regionQc"
#  [11] "ses_postalCode"
#  [12] "ses_language"
#  [13] "ses_religion"
#  [14] "ses_religionBigFive"
#  [15] "ses_religion_bin"
#  [16] "ses_religiosity"
#  [17] "ses_educ"
#  [18] "ses_educ_5Cat"
#  [19] "ses_educ_3Cat"
#  [20] "ses_income"
#  [21] "ses_income3Cat"
#  [22] "ses_incomeCensus"
#  [23] "ses_englishSkills"
#  [24] "ses_frenchSkills"
#  [25] "ses_rurality"
#  [26] "ses_matStatus"
#  [27] "ses_owner"
#  [28] "ses_householdComp"
#  [29] "ses_occupation"
#  [30] "ses_occupation_5Cat"
#  [31] "ses_children"
#  [32] "ses_ethnicity"
#  [33] "ses_ethnicityWhite"
#  [34] "ses_ethnicityWB"
#  [35] "ses_sexOrientation"
#  [36] "ses_sexOrientationHetero"
#  [37] "ses_parentImmigrant"
#  [38] "ses_immigrant"
#  [39] "ses_dwelling"
#  [40] "ses_dwelling_cat"
#  [41] "ses_dwellingApp"
#  [42] "ses_dwellingLoft"
#  [43] "ses_dwellingCondo"
#  [44] "ses_dwellingTour"
#  [45] "ses_dwellingDetachedHouse"
#  [46] "ses_dwellingTownhouse"
#  [47] "ses_dwellingDuplex"
#  [48] "ses_dwellingCoop"
#  [49] "ses_dwellingHLM"
#  [50] "ses_dwellingMobile"
#  [51] "ses_dwellingOther"
#  [52] "lifestyle_exercise"
#  [53] "lifestyle_exerciseGym"
#  [54] "lifestyle_exerciseTeamSport"
#  [55] "lifestyle_exerciseWalk"
#  [56] "lifestyle_exerciseRun"
#  [57] "lifestyle_exerciseYoga"
#  [58] "lifestyle_exerciseSwim"
#  [59] "lifestyle_exerciseOther"
#  [60] "lifestyle_exerciseNone"
#  [61] "lifestyle_goFishingFreq"
#  [62] "lifestyle_goFishingFreq_factor"
#  [63] "lifestyle_goFishingFreq_numeric"
#  [64] "lifestyle_goFishingFreq_bin"
#  [65] "lifestyle_goHuntingFreq"
#  [66] "lifestyle_goHuntingFreq_factor"
#  [67] "lifestyle_goHuntingFreq_numeric"
#  [68] "lifestyle_goHuntingFreq_bin"
#  [69] "lifestyle_snowSportsFreq"
#  [70] "lifestyle_snowSportsFreq_factor"
#  [71] "lifestyle_snowSportsFreq_numeric"
#  [72] "lifestyle_snowSportsFreq_bin"
#  [73] "lifestyle_teamSportsFreq"
#  [74] "lifestyle_teamSportsFreq_factor"
#  [75] "lifestyle_teamSportsFreq_numeric"
#  [76] "lifestyle_teamSportsFreq_bin"
#  [77] "lifestyle_goMuseumsFreq"
#  [78] "lifestyle_goMuseumsFreq_factor"
#  [79] "lifestyle_goMuseumsFreq_numeric"
#  [80] "lifestyle_goMuseumsFreq_bin"
#  [81] "lifestyle_performingArtsFreq"
#  [82] "lifestyle_performingArtsFreq_factor"
#  [83] "lifestyle_performingArtsFreq_numeric"
#  [84] "lifestyle_performingArtsFreq_bin"
#  [85] "lifestyle_manualTaskFreq"
#  [86] "lifestyle_manualTaskFreq_factor"
#  [87] "lifestyle_manualTaskFreq_numeric"
#  [88] "lifestyle_manualTaskFreq_bin"
#  [89] "lifestyle_motorizedActFreq"
#  [90] "lifestyle_motorizedActFreq_factor"
#  [91] "lifestyle_motorizedActFreq_numeric"
#  [92] "lifestyle_motorizedActFreq_bin"
#  [93] "lifestyle_unmotorizedActFreq"
#  [94] "lifestyle_unmotorizedActFreq_factor"
#  [95] "lifestyle_unmotorizedActFreq_numeric"
#  [96] "lifestyle_unmotorizedActFreq_bin"
#  [97] "lifestyle_volunteeringFreq"
#  [98] "lifestyle_volunteeringFreq_factor"
#  [99] "lifestyle_volunteeringFreq_numeric"
# [100] "lifestyle_volunteeringFreq_bin"
# [101] "lifestyle_makeArtFreq"
# [102] "lifestyle_makeArtFreq_factor"
# [103] "lifestyle_makeArtFreq_numeric"
# [104] "lifestyle_makeArtFreq_bin"
# [105] "lifestyle_travelFreq"
# [106] "lifestyle_travelFreq_factor"
# [107] "lifestyle_travelFreq_numeric"
# [108] "lifestyle_travelFreq_bin"
# [109] "lifestyle_gamingFreq"
# [110] "lifestyle_gamingFreq_factor"
# [111] "lifestyle_gamingFreq_numeric"
# [112] "lifestyle_gamingFreq_bin"
# [113] "lifestyle_typeTransport"
# [114] "lifestyle_typeTransportCar"
# [115] "lifestyle_typeTransportSUV"
# [116] "lifestyle_typeTransportMoto"
# [117] "lifestyle_typeTransportWalk"
# [118] "lifestyle_typeTransportBicycle"
# [119] "lifestyle_typeTransportPublicTransit"
# [120] "lifestyle_typeTransportCarpooling"
# [121] "lifestyle_typeTransportCarsharing"
# [122] "lifestyle_choiceTransport"
# [123] "lifestyle_transportIdentity_bin"
# [124] "lifestyle_transportEfficiency_bin"
# [125] "lifestyle_workField"
# [126] "lifestyle_workType"
# [127] "lifestyle_consClothes"
# [128] "lifestyle_consClothesDepartment"
# [129] "lifestyle_consClothesIndependent"
# [130] "lifestyle_consClothesChain"
# [131] "lifestyle_consClothesSuperstores"
# [132] "lifestyle_consClothesOnline"
# [133] "lifestyle_consClothesFrip"
# [134] "lifestyle_consClothesOther"
# [135] "lifestyle_followFashion"
# [136] "lifestyle_eatMeatFreq"
# [137] "lifestyle_fridgeVegetalMilk"
# [138] "lifestyle_fridgeTofuTempeh"
# [139] "lifestyle_fridgeEnergyDrink"
# [140] "lifestyle_fridgePizza"
# [141] "lifestyle_fridgeButterTarts"
# [142] "lifestyle_fridgeBacon"
# [143] "lifestyle_fridgeCeasarDressing"
# [144] "lifestyle_fridgeOrganicVeggies"
# [145] "lifestyle_fridgeHotSauce"
# [146] "lifestyle_fridgeSoftDrinks"
# [147] "lifestyle_fridgeGroundBeef"
# [148] "lifestyle_consCoffee"
# [149] "lifestyle_consCoffeeTimHortons"
# [150] "lifestyle_consCoffeeStarbucks"
# [151] "lifestyle_consCoffeeSecondCup"
# [152] "lifestyle_consCoffeeMcDo"
# [153] "lifestyle_consCoffeeOther"
# [154] "lifestyle_consCoffeeIndependent"
# [155] "lifestyle_consCoffeeNone"
# [156] "lifestyle_makeCoffee"
# [157] "lifestyle_ownPet"
# [158] "lifestyle_ownPet_bin"
# [159] "lifestyle_ownPetCat"
# [160] "lifestyle_ownPetDog"
# [161] "lifestyle_ownPetCatAndDog"
# [162] "lifestyle_ownPetDiverseAnimals"
# [163] "lifestyle_ownPetOther"
# [164] "lifestyle_ownPetFarmAnimals"
# [165] "lifestyle_ownPetNone"
# [166] "lifestyle_smokeFreq"
# [167] "lifestyle_favAlcool"
# [168] "lifestyle_favAlcoolRedWine"
# [169] "lifestyle_favAlcoolWhiteWine"
# [170] "lifestyle_favAlcoolRoseWine"
# [171] "lifestyle_favAlcoolBubbleDrink"
# [172] "lifestyle_favAlcoolBeer"
# [173] "lifestyle_favAlcoolMicroBeer"
# [174] "lifestyle_favAlcoolSpirits"
# [175] "lifestyle_favAlcoolCocktail"
# [176] "lifestyle_favAlcoolDontDrink"
# [177] "lifestyle_alcoolFreq"
# [178] "lifestyle_weedFreq"
# [179] "lifestyle_mostFreqSocialMedia"
# [180] "lifestyle_socialMediaTime"
# [181] "lifestyle_clothingStyle"
# [182] "lifestyle_clothingStyleGroups"
# [183] "lifestyle_clothingStyleFormal"
# [184] "lifestyle_clothingStyleClassic"
# [185] "lifestyle_clothingStyleCasual"
# [186] "lifestyle_clothingStyleSport"
# [187] "lifestyle_clothingStyleElegant"
# [188] "lifestyle_clothingStyleHippie"
# [189] "lifestyle_clothingStylePunk"
# [190] "lifestyle_clothingStyleRock"
# [191] "lifestyle_clothingStyleOther"
# [192] "lifestyle_numberTattoos"
# [193] "lifestyle_hasTattoos"
# [194] "lifestyle_typeMorningToEvening"
# [195] "lifestyle_typeTravel"
# [196] "values_conformityFreethinking"
# [197] "values_curiosityGoodmanners"
# [198] "values_selfrelianceObedience"
# [199] "values_considerateWellbehaved"
# [200] "values_worldDangerous"
# [201] "values_isolationismPol"
# [202] "values_polarizationLiberals"
# [203] "values_polarizationConservatives"
# [204] "values_polarizationNeoDem"
# [205] "values_polarizationBloc"
# [206] "values_polarizationGreen"
# [207] "values_polarizationPeopleParty"
# [208] "dv_turnout"
# [209] "dv_voteChoice"
# [210] "dv_voteChoiceAllOptions"
# [211] "dv_voteChoiceLPC"
# [212] "dv_voteChoiceCPC"
# [213] "dv_voteChoiceNDP"
# [214] "dv_voteChoiceBQ"
# [215] "dv_voteChoiceGPC"
# [216] "dv_voteChoiceOther"
# [217] "dv_voteCertainty"
# [218] "dv_potgrowthLPC"
# [219] "dv_potgrowthCPC"
# [220] "dv_potgrowthNDP"
# [221] "dv_potgrowthBQ"
# [222] "dv_potgrowthGPC"
# [223] "dv_potgrowthPPC"
# [224] "dv_turnout2021_bin"
# [225] "dv_potgrowthQcCAQ"
# [226] "dv_potgrowthQcPLQ"
# [227] "dv_potgrowthQcQS"
# [228] "dv_potgrowthQcPQ"
# [229] "dv_potgrowthQcPCQ"
# [230] "dv_attitudeLeftvsRight"
# [231] "dv_partyId"
# [232] "dv_peoplePredCPC"
# [233] "dv_peoplePredLPC"
# [234] "dv_peoplePredNDP"
# [235] "dv_peoplePredBQ"
# [236] "dv_peoplePredGPC"
# [237] "dv_peoplePredPPC"
# [238] "dv_peoplePredMajority"
# [239] "issue_proReconcilAboriginals"
# [240] "issue_proImmigration"
# [241] "issue_proBorderControl"
# [242] "issue_proGunControl"
# [243] "issue_reduceDeficit"
# [244] "issue_proPrivateHealth"
# [245] "issue_proUnions"
# [246] "issue_proQcIndependance"
# [247] "issue_protectFrench"
# [248] "isue_religiousAccomodations"
# [249] "issue_proSexEduc"
# [250] "issue_proCarbonTax"
# [251] "issue_supportOil"
# [252] "issue_climateChangeExaggerated"
# [253] "issue_proLgbtqRights"
# [254] "issue_proIsrael"
# [255] "issue_helpUkraine"
# [256] "issue_mostImportant"
# [257] "issue_goodEcon"
# [258] "issue_proDistinctUSA"
# [259] "issue_anthemBilingual"
# [260] "issue_concernImmigIllegal"
# [261] "issue_immigNoHouse"
# [262] "issue_gouvActHouse"
# [263] "issue_bilingualCan"
# [264] "issue_welfareNotDeserve"
# [265] "issue_gouvNoMoreTax"

# %%
# Join both datasets to have cluster, lifestyle and id

# Sélectionner les variables lifestyle et SES de dfLifestyle
dfLifestyle_selected <- dfLifestyle %>%
  select(id, lifestyle_exercise, lifestyle_goFishingFreq_bin, lifestyle_goHuntingFreq_bin, lifestyle_goMuseumsFreq_bin, lifestyle_motorizedActFreq_bin, lifestyle_unmotorizedActFreq_bin, lifestyle_volunteeringFreq_bin, lifestyle_typeTransport, lifestyle_makeArtFreq_bin, lifestyle_travelFreq_bin, lifestyle_consClothes, lifestyle_eatMeatFreq, lifestyle_fridgeVegetalMilk, lifestyle_fridgeTofuTempeh, lifestyle_fridgeOrganicVeggies, lifestyle_consCoffee, lifestyle_ownPet, lifestyle_favAlcool, lifestyle_hasTattoos, lifestyle_workType, lifestyle_typeTravel, ses_gender, ses_age_4Cat, ses_educ_3Cat, ses_income3Cat, ses_dwelling)

# Sélectionner les variables clusters de dfUsedForClustering
dfClusters_selected <- dfUsedForClustering %>%
  select(id, cluster_name, starts_with("cluster_"))

# Fusionner les deux jeux de données sur id
dfValidation <- dfClusters_selected %>%
  inner_join(dfLifestyle_selected, by = "id")

# Voir les variables de ce jeu fusionné
names(dfValidation)
# Out:
#  [1] "id"                               "cluster_name"
#  [3] "cluster_3"                        "cluster_1"
#  [5] "cluster_6"                        "cluster_2"
#  [7] "cluster_7"                        "cluster_8"
#  [9] "cluster_4"                        "cluster_5"
# [11] "cluster_9"                        "lifestyle_exercise"
# [13] "lifestyle_goFishingFreq_bin"      "lifestyle_goHuntingFreq_bin"
# [15] "lifestyle_goMuseumsFreq_bin"      "lifestyle_motorizedActFreq_bin"
# [17] "lifestyle_unmotorizedActFreq_bin" "lifestyle_volunteeringFreq_bin"
# [19] "lifestyle_typeTransport"          "lifestyle_makeArtFreq_bin"
# [21] "lifestyle_travelFreq_bin"         "lifestyle_consClothes"
# [23] "lifestyle_eatMeatFreq"            "lifestyle_fridgeVegetalMilk"
# [25] "lifestyle_fridgeTofuTempeh"       "lifestyle_fridgeOrganicVeggies"
# [27] "lifestyle_consCoffee"             "lifestyle_ownPet"
# [29] "lifestyle_favAlcool"              "lifestyle_hasTattoos"
# [31] "lifestyle_workType"               "lifestyle_typeTravel"
# [33] "ses_gender"                       "ses_age_4Cat"
# [35] "ses_educ_3Cat"                    "ses_income3Cat"
# [37] "ses_dwelling"

# %%
generate_graph <- function(data, lifestyle_variable, output_path) {
  
  # Convertir la variable en symbole pour dplyr et ggplot
  lifestyle_sym <- sym(lifestyle_variable)

  # Calculer proportions et créer le graphique
  graph <- data %>%
    group_by(cluster_name, !!lifestyle_sym) %>%
    summarise(nombre_de_repondants = n(), .groups = "drop") %>%
    group_by(cluster_name) %>%
    mutate(
      nombre_total_de_repondants = sum(nombre_de_repondants),
      proportion = nombre_de_repondants / nombre_total_de_repondants
    ) %>%
    ggplot(aes(x = !!lifestyle_sym, y = proportion, fill = factor(cluster_name))) +
    geom_col() +
    facet_wrap(~ cluster_name) +
    labs(
      x = lifestyle_variable,  
      y = "Proportion",
      fill = "Cluster",
      title = paste("Distribution of", lifestyle_variable, "by Cluster")
    ) +
    theme_minimal() +
    theme(axis.text.x = element_text(angle = 45, hjust = 1))  # Rotation à 45° des labels de l'axe x
  
  # Sauvegarder le graphique
  ggsave(
    filename = paste0(output_path, "/validationCluster_", lifestyle_variable, ".pdf"),
    plot = graph,
    width = 16,
    height = 12
  )
}

# %%
# Lister toutes les variables de lifestyle

lifestyle_list <- colnames(dfValidation)[grepl("^lifestyle_", colnames(dfValidation))]
ses_list <- colnames(dfValidation)[grepl("^ses_", colnames(dfValidation))]
variable_list <- c(lifestyle_list, ses_list)

# %%
# Lancer une boucle pour générer tous les graphiques

# Spécifier le dossier où enregistrer les graphiques
output_path <- "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle"

# Générer un graphique pour chaque enjeu sélectionné
lapply(variable_list, function(lifestyle) {
  generate_graph(dfValidation, lifestyle, output_path)
})
# Out:
# [[1]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_exercise.pdf"
#
# [[2]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_goFishingFreq_bin.pdf"
#
# [[3]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_goHuntingFreq_bin.pdf"
#
# [[4]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_goMuseumsFreq_bin.pdf"
#
# [[5]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_motorizedActFreq_bin.pdf"
#
# [[6]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_unmotorizedActFreq_bin.pdf"
#
# [[7]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_volunteeringFreq_bin.pdf"
#
# [[8]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_typeTransport.pdf"
#
# [[9]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_makeArtFreq_bin.pdf"
#
# [[10]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_travelFreq_bin.pdf"
#
# [[11]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_consClothes.pdf"
#
# [[12]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_eatMeatFreq.pdf"
#
# [[13]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_fridgeVegetalMilk.pdf"
#
# [[14]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_fridgeTofuTempeh.pdf"
#
# [[15]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_fridgeOrganicVeggies.pdf"
#
# [[16]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_consCoffee.pdf"
#
# [[17]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_ownPet.pdf"
#
# [[18]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_favAlcool.pdf"
#
# [[19]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_hasTattoos.pdf"
#
# [[20]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_workType.pdf"
#
# [[21]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_lifestyle_typeTravel.pdf"
#
# [[22]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_ses_gender.pdf"
#
# [[23]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_ses_age_4Cat.pdf"
#
# [[24]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_ses_educ_3Cat.pdf"
#
# [[25]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_ses_income3Cat.pdf"
#
# [[26]]
# [1] "../../_PrivateFolder_datagotchi_federal_2025/graph/clustering/can_2025/lifestyle/validationCluster_ses_dwelling.pdf"
